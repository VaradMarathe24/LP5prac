# %%
# !pip uninstall numpy h5py tensorflow -y
# Out:
# ^C
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4

# %%
# !pip install numpy==1.26.4
# !pip install h5py==3.11.0
# !pip install tensorflow==2.19.0
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Requirement already satisfied: h5py==3.11.0 in c:\users\varad\anaconda3\lib\site-packages (3.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\varad\anaconda3\lib\site-packages (from h5py==3.11.0) (1.26.4)
# Collecting tensorflow==2.19.0
#   Using cached tensorflow-2.19.0-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (3.12.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\varad\anaconda3\lib\site-packages (from tensorflow==2.19.0) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\varad\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.19.0) (0.44.0)
# Requirement already satisfied: rich in c:\users\varad\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow==2.19.0) (13.7.1)
# Requirement already satisfied: namex in c:\users\varad\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow==2.19.0) (0.1.0)
# Requirement already satisfied: optree in c:\users\varad\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow==2.19.0) (0.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varad\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varad\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varad\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varad\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\varad\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow==2.19.0) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\varad\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow==2.19.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\varad\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow==2.19.0) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\varad\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow==2.19.0) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\varad\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow==2.19.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\varad\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow==2.19.0) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\varad\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.19.0) (0.1.0)
# Using cached tensorflow-2.19.0-cp312-cp312-win_amd64.whl (376.0 MB)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-2.19.0

# %%
import numpy as np

# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(train_x, train_y), (test_x, test_y) = fashion_mnist.load_data()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, MaxPooling2D, Conv2D

# %%
model = Sequential()

# %%
model.add(Conv2D(filters=64,kernel_size=(3,3),activation='relu',input_shape=(28, 28, 1)))
# Adding maxpooling layer to get max value within a matrix
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128, activation = "relu"))
model.add(Dense(10, activation = "softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 26, 26, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 10816)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │       1,384,576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,386,506 (5.29 MB)
#  Trainable params: 1,386,506 (5.29 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(train_x.astype(np.float32), train_y.astype(np.float32), epochs = 5, validation_split = 0.2)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 40s 24ms/step - accuracy: 0.8428 - loss: 1.4257 - val_accuracy: 0.8779 - val_loss: 0.3628
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.8976 - loss: 0.2912 - val_accuracy: 0.8937 - val_loss: 0.3071
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 43s 29ms/step - accuracy: 0.9101 - loss: 0.2487 - val_accuracy: 0.8932 - val_loss: 0.3164
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 82s 29ms/step - accuracy: 0.9189 - loss: 0.2232 - val_accuracy: 0.8920 - val_loss: 0.3224
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 25ms/step - accuracy: 0.9224 - loss: 0.2090 - val_accuracy: 0.8905 - val_loss: 0.3449

# %%
loss, acc = model.evaluate(test_x, test_y)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8858 - loss: 0.3645

# %%
labels = ['t_shirt', 'trouser', 'pullover', 'dress', 'coat', 'sandal', 'shirt', 'sneaker',   'bag', 'ankle_boots']

# %%
predictions = model.predict(test_x[:1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step

# %%
import numpy as np
label = labels[np.argmax(predictions)]
import matplotlib.pyplot as plt
print(label)
plt.imshow(test_x[:1][0])
plt.show
# Out:
# ankle_boots
# <function matplotlib.pyplot.show(close=None, block=None)>
